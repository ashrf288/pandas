# %% [markdown]
# ###
#
# `df=pd.read_csv('vgsales.csv')`
#
# if it  have index col  and dates use the line below
#
# `df = pd.read_csv("data/vgsales.csv", index_col=0, parse_dates=True)`

# %%
import pandas as pd

df=pd.read_csv('vgsales.csv')
data=df
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
NA_SALES=df['NA_Sales']
NA_SALES.min()
# Out:
# 0.0

# %% [markdown]
# each col is called a series and has a label to help you access to it  you can run methods on it like min and
# max
# Getting data in to pandas from many different file formats or data sources is supported by read_* functions.
#
# Exporting data out of pandas is provided by different to_*methods.
#
# The head/tail/info methods and the dtypes attribute are convenient for a first check.

# %% [markdown]
# to get one series  use ['label']  one label   first bracket is called selection brackts
#
# to get more than one series  use [['label1','label2']]   array of labels

# %%
df[['NA_Sales','Name']]
# Out:
#        NA_Sales                                              Name
# 0         41.49                                        Wii Sports
# 1         29.08                                 Super Mario Bros.
# 2         15.85                                    Mario Kart Wii
# 3         15.75                                 Wii Sports Resort
# 4         11.27                          Pokemon Red/Pokemon Blue
# ...         ...                                               ...
# 16593      0.01                Woody Woodpecker in Crazy Castle 5
# 16594      0.01                     Men in Black II: Alien Escape
# 16595      0.00  SCORE International Baja 1000: The Official Game
# 16596      0.00                                        Know How 2
# 16597      0.01                                  Spirits & Spells
#
# [16598 rows x 2 columns]

# %% [markdown]
# To select rows based on a conditional expression, use a condition inside the selection brackets [].

# %%
df[ df['NA_Sales'] > 15 ]
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 2     3     Mario Kart Wii      Wii  2008.0    Racing  Nintendo     15.85
# 3     4  Wii Sports Resort      Wii  2009.0    Sports  Nintendo     15.75
# 5     6             Tetris       GB  1989.0    Puzzle  Nintendo     23.20
# 9    10          Duck Hunt      NES  1984.0   Shooter  Nintendo     26.93
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 5      2.26      4.22         0.58         30.26
# 9      0.63      0.28         0.47         28.31

# %%
df[df['Platform']=='Wii']
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df[df['Platform'].isin(['Wii','GB'])]
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# The notna() conditional function returns a True for each row the values are not an Null value. As such, this can be combined with the selection brackets [] to filter the data table
#
# `df[df["Name"].notna()]`

# %% [markdown]
# ## filter specific rows
# 1- loc
#
# `df.loc[filter,returned]`
#
# 2-iloc
#
# `df.iloc[ rows , col ]`
#
#
# 3- You can assign new values to a selection based on loc/iloc.

# %%
df.loc[df['Genre']=='Sports','Name']
# Out:
# 0                           Wii Sports
# 3                    Wii Sports Resort
# 13                             Wii Fit
# 14                        Wii Fit Plus
# 77                             FIFA 16
#                      ...
# 16576                Rugby Challenge 3
# 16578    Outdoors Unleashed: Africa 3D
# 16579                PGA European Tour
# 16581                        Fit & Fun
# 16587         Mezase!! Tsuri Master DS
# Name: Name, Length: 2346, dtype: object

# %%
df.iloc[9:25, 2:5]
# Out:
#    Platform    Year         Genre
# 9       NES  1984.0       Shooter
# 10       DS  2005.0    Simulation
# 11       DS  2005.0        Racing
# 12       GB  1999.0  Role-Playing
# 13      Wii  2007.0        Sports
# 14      Wii  2009.0        Sports
# 15     X360  2010.0          Misc
# 16      PS3  2013.0        Action
# 17      PS2  2004.0        Action
# 18     SNES  1990.0      Platform
# 19       DS  2005.0          Misc
# 20       DS  2006.0  Role-Playing
# 21       GB  1989.0      Platform
# 22      NES  1988.0      Platform
# 23     X360  2013.0        Action
# 24      PS2  2002.0        Action

# %% [markdown]
# ##

# %% [markdown]
# ## most_common_publisher

# %%
most_common_publisher_data=data['Publisher'].mode()
most_common_publisher=most_common_publisher_data[0]
most_common_publisher
# Out:
# 'Electronic Arts'

# %% [markdown]
# ## most_common_platform

# %%
most_common_platform_data=data['Platform'].mode()
most_common_platform=most_common_platform_data[0]
most_common_platform
# Out:
# 'DS'

# %% [markdown]
# ## most_common_genre

# %%
most_common_genre_data=data['Genre'].mode()
most_common_genre=most_common_genre_data[0]
most_common_genre
# Out:
# 'Action'

# %% [markdown]
# ## 2- higthest growing

# %%
higest_grossing=data.nlargest(20,'Global_Sales')
top_twenty_highest_grossing_games=higest_grossing
top_twenty_highest_grossing_games
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
top_twenty_highest_grossing_games.iloc[19]
# Out:
# Rank                                                      20
# Name            Brain Age: Train Your Brain in Minutes a Day
# Platform                                                  DS
# Year                                                  2005.0
# Genre                                                   Misc
# Publisher                                           Nintendo
# NA_Sales                                                4.75
# EU_Sales                                                9.26
# JP_Sales                                                4.16
# Other_Sales                                             2.05
# Global_Sales                                           20.22
# Name: 19, dtype: object

# %%
data.sort_values(by=['NA_Sales'],ascending=False)
data.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# ## median for NA_SALES

# %%
na_median_sales=data['NA_Sales'].median()
print(na_median_sales)
# Out:
# 0.08

# %%
res=data.loc[data['NA_Sales'] == na_median_sales].head(10)
res
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 446   1990.0  Role-Playing              Enix Corporation      0.08      0.00
# ...

# %% [markdown]
# ## For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
standard_deviation = data['NA_Sales'].std()
mean = data['NA_Sales'].mean()
top_seles = data['NA_Sales'].iloc[0]
sales_in_range=(top_seles-mean) / standard_deviation
sales_in_range
# Out:
# 50.47898767479108

# %% [markdown]
# ## The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
wii_sales = df[ df['Platform']=='Wii' ].Global_Sales
other_platforms = df[ df['Platform']!='Wii' ].Global_Sales
nentendo_outdone=wii_sales.mean()-other_platforms.mean()
nentendo_outdone
# Out:
# 0.17601413173327207

# %%
other_platforms
# Out:
# 1        40.24
# 4        31.37
# 5        30.26
# 6        30.01
# 9        28.31
#          ...
# 16593     0.01
# 16594     0.01
# 16595     0.01
# 16596     0.01
# 16597     0.01
# Name: Global_Sales, Length: 15273, dtype: float64

# %% [markdown]
# ## standerd divieation for for na_sales (added question)

# %%
#question1
std_for_higher_sales=data['NA_Sales'].std()
std_for_higher_sales
# Out:
# 0.8166830292988796

# %% [markdown]
# ## 10 latest games (added qustion )

# %%
#question2
latest_games=data.sort_values(by=['Year'],ascending=False).head(10)
latest_games
# Out:
#         Rank                                              Name Platform  \
# 5957    5959                            Imagine: Makeup Artist       DS
# 14390  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16241  16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16438  16441                  Brothers Conflict: Precious Baby      PSV
# 8293    8295                      Shin Megami Tensei IV: Final      3DS
# 13647  13649                                     Hitman (2016)      PS4
# 13596  13598      Card Fight!! Vanguard G: Stride to Victory!!      3DS
# 13602  13604        Refrain no Chika Meikyuu to Majo no Ryodan      PSV
# 13614  13616                  Utawarerumono: Futari no Hakuoro      PS4
# 13620  13622                 Kamen Rider: Battride War Genesis      PS3
#
#          Year         Genre             Publisher  NA_Sales  EU_Sales  \
# 5957   2020.0    Simulation               Ubisoft      0.27      0.00
# ...

# %% [markdown]
# ## games with higthes midean globally (added question)

# %%
#Question3
median_game_sales = data['Global_Sales'].median()
median_game_sales

highly_ten_games=data[data['Global_Sales']==median_game_sales].head(10)
highly_ten_games.iloc[1].Name
# Out:
# 'The Suffering: Ties That Bind'

# %%
def assert_equal(actual,expected):
    assert actual == expected, f"Expected {expected} but got {actual}"
def test():
    assert_equal(most_common_publisher, 'Electronic Arts')
    assert_equal(most_common_platform, 'DS')
    assert_equal(most_common_genre, 'Action')
    assert_equal(top_twenty_highest_grossing_games.iloc[0].Name, 'Wii Sports')
    assert_equal(top_twenty_highest_grossing_games.iloc[19].Name, 'Brain Age: Train Your Brain in Minutes a Day')
    assert_equal(na_median_sales, 0.08)
    assert_equal(sales_in_range, 50.47898767479108)
    assert_equal(nentendo_outdone, 0.17601413173327207)
    assert_equal(std_for_higher_sales, 0.8166830292988796)
    assert_equal(latest_games.iloc[0].Name, 'Imagine: Makeup Artist')
    assert_equal(highly_ten_games.iloc[1].Name, 'The Suffering: Ties That Bind')

    print("Success!!!")

test()
# Out:
# Success!!!

# %%
most_common_publisher
# Out:
# 'Electronic Arts'
